# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Launch Sites Locations Analysis with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
# !pip3 install folium
# !pip3 install wget
# Out:
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 8.8 MB/s  eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from folium) (1.20.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from folium) (2.26.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from folium) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->folium) (1.26.7)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=5ee525967c5b1ef64e25b9054c8d8964c9732a1fcacee12818a7cab6fd945d57
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import folium
import wget
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_3/DV0101EN-3-5-1-Generating-Maps-in-Python-py-v2.0.ipynb)

# %% [markdown]
# ## Task 1: Mark all launch sites on a map

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
spacex_csv_file = wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')
spacex_df=pd.read_csv(spacex_csv_file)

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba750521be74a009380d6d75b158076e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba750521be74a009380d6d75b158076e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ba750521be74a009380d6d75b158076e = L.map(
#                 &quot;map_ba750521be74a009380d6d75b158076e&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de60c59a256559a8fa953619924d3e0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba750521be74a009380d6d75b158076e);
#
#
#             var circle_8a39a3f5b764ca71392a95d7cd089fa2 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba750521be74a009380d6d75b158076e);
#
#
#         var popup_3c31d78cfaf1f7e42e14866dc2512764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d6fd60cfb8396d9c5be004f63f455f16 = $(`&lt;div id=&quot;html_d6fd60cfb8396d9c5be004f63f455f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#             popup_3c31d78cfaf1f7e42e14866dc2512764.setContent(html_d6fd60cfb8396d9c5be004f63f455f16);
#
#
#         circle_8a39a3f5b764ca71392a95d7cd089fa2.bindPopup(popup_3c31d78cfaf1f7e42e14866dc2512764)
#         ;
#
#
#
#
#             var marker_4abf97a97e226ceac1c7e88479077965 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_ba750521be74a009380d6d75b158076e);
#
#
#             var div_icon_a4004b19b4c0728e61c3e26ee3f55ffa = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_4abf97a97e226ceac1c7e88479077965.setIcon(div_icon_a4004b19b4c0728e61c3e26ee3f55ffa);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
for i,r in launch_sites_df.iterrows():
    coordinate = [r.Lat, r.Long]
    circle = folium.Circle(coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup(r['Launch Site']))
    marker = folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % r['Launch Site'], ))
    site_map.add_child(circle)
    site_map.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7433eda5e30fa239bf21ccac5c93b8d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7433eda5e30fa239bf21ccac5c93b8d1 = L.map(
#                 &quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bc08ae4d61e4a0f30a6a3d90dc099cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var circle_6836870cc95664cdedb8ff27e7b36775 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_5fd0032ab407beec48f6bbc058c696bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_765b0e0ebb2743773a4ed2e51f6bf3b4 = $(`&lt;div id=&quot;html_765b0e0ebb2743773a4ed2e51f6bf3b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#             popup_5fd0032ab407beec48f6bbc058c696bd.setContent(html_765b0e0ebb2743773a4ed2e51f6bf3b4);
#
#
#         circle_6836870cc95664cdedb8ff27e7b36775.bindPopup(popup_5fd0032ab407beec48f6bbc058c696bd)
#         ;
#
#
#
#
#             var marker_2cf6c28528b6b0a339b7b8ac4b3c8d98 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_0349f1d1c9dca8f28e5d4d1baae9939d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_2cf6c28528b6b0a339b7b8ac4b3c8d98.setIcon(div_icon_0349f1d1c9dca8f28e5d4d1baae9939d);
#
#
#             var circle_d7af11820a10e23a8be13867d9ee051f = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_a6764e96a121706a5150cc80d2178cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3b4ea0e9d4bc9be6138e4295d666678 = $(`&lt;div id=&quot;html_f3b4ea0e9d4bc9be6138e4295d666678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#             popup_a6764e96a121706a5150cc80d2178cab.setContent(html_f3b4ea0e9d4bc9be6138e4295d666678);
#
#
#         circle_d7af11820a10e23a8be13867d9ee051f.bindPopup(popup_a6764e96a121706a5150cc80d2178cab)
#         ;
#
#
#
#
#             var marker_6e4c61a95c0f589a254b6175d708c8c3 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_75437d8d08efc7da8af66ce66cb3ee80 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_6e4c61a95c0f589a254b6175d708c8c3.setIcon(div_icon_75437d8d08efc7da8af66ce66cb3ee80);
#
#
#             var circle_7ab8db1b087398d57738eb772ecf38e7 = L.circle(
#                 [28.57325457, -80.64689529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lin

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png" />
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %% [markdown]
# # Task 2: Mark the success/failed launches for each site on the map

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# *TODO:* Create a new column in `launch_sites` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red
spacex_df.loc[spacex_df['class']==1, 'marker_color']='green'
spacex_df.loc[spacex_df['class']==0, 'marker_color']='red'
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %%
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    # marker = folium.Marker(...)
    icon = folium.Icon(color='white', icon_color=record['marker_color'])
    marker = folium.Marker(location=[record.Lat,record.Long],icon=icon)
    marker_cluster.add_child(marker)

site_map.add_child(marker_cluster)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7433eda5e30fa239bf21ccac5c93b8d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7433eda5e30fa239bf21ccac5c93b8d1 = L.map(
#                 &quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bc08ae4d61e4a0f30a6a3d90dc099cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var circle_6836870cc95664cdedb8ff27e7b36775 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_5fd0032ab407beec48f6bbc058c696bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_765b0e0ebb2743773a4ed2e51f6bf3b4 = $(`&lt;div id=&quot;html_765b0e0ebb2743773a4ed2e51f6bf3b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#             popup_5fd0032ab407beec48f6bbc058c696bd.setContent(html_765b0e0ebb2743773a4ed2e51f6bf3b4);
#
#
#         circle_6836870cc95664cdedb8ff27e7b36775.bindPopup(popup_5fd0032ab407beec48f6bbc058c696bd)
#         ;
#
#
#
#
#             var marker_2cf6c28528b6b0a339b7b8ac4b3c8d98 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_0349f1d1c9dca8f28e5d4d1baae9939d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_2cf6c28528b6b0a339b7b8ac4b3c8d98.setIcon(div_icon_0349f1d1c9dca8f28e5d4d1baae9939d);
#
#
#             var circle_d7af11820a10e23a8be13867d9ee051f = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_a6764e96a121706a5150cc80d2178cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3b4ea0e9d4bc9be6138e4295d666678 = $(`&lt;div id=&quot;html_f3b4ea0e9d4bc9be6138e4295d666678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#             popup_a6764e96a121706a5150cc80d2178cab.setContent(html_f3b4ea0e9d4bc9be6138e4295d666678);
#
#
#         circle_d7af11820a10e23a8be13867d9ee051f.bindPopup(popup_a6764e96a121706a5150cc80d2178cab)
#         ;
#
#
#
#
#             var marker_6e4c61a95c0f589a254b6175d708c8c3 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_75437d8d08efc7da8af66ce66cb3ee80 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_6e4c61a95c0f589a254b6175d708c8c3.setIcon(div_icon_75437d8d08efc7da8af66ce66cb3ee80);
#
#
#             va

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png" />
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png" />
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7433eda5e30fa239bf21ccac5c93b8d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7433eda5e30fa239bf21ccac5c93b8d1 = L.map(
#                 &quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bc08ae4d61e4a0f30a6a3d90dc099cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var circle_6836870cc95664cdedb8ff27e7b36775 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_5fd0032ab407beec48f6bbc058c696bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_765b0e0ebb2743773a4ed2e51f6bf3b4 = $(`&lt;div id=&quot;html_765b0e0ebb2743773a4ed2e51f6bf3b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#             popup_5fd0032ab407beec48f6bbc058c696bd.setContent(html_765b0e0ebb2743773a4ed2e51f6bf3b4);
#
#
#         circle_6836870cc95664cdedb8ff27e7b36775.bindPopup(popup_5fd0032ab407beec48f6bbc058c696bd)
#         ;
#
#
#
#
#             var marker_2cf6c28528b6b0a339b7b8ac4b3c8d98 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_0349f1d1c9dca8f28e5d4d1baae9939d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_2cf6c28528b6b0a339b7b8ac4b3c8d98.setIcon(div_icon_0349f1d1c9dca8f28e5d4d1baae9939d);
#
#
#             var circle_d7af11820a10e23a8be13867d9ee051f = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_a6764e96a121706a5150cc80d2178cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3b4ea0e9d4bc9be6138e4295d666678 = $(`&lt;div id=&quot;html_f3b4ea0e9d4bc9be6138e4295d666678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#             popup_a6764e96a121706a5150cc80d2178cab.setContent(html_f3b4ea0e9d4bc9be6138e4295d666678);
#
#
#         circle_d7af11820a10e23a8be13867d9ee051f.bindPopup(popup_a6764e96a121706a5150cc80d2178cab)
#         ;
#
#
#
#
#             var marker_6e4c61a95c0f589a254b6175d708c8c3 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_75437d8d08efc7da8af66ce66cb3ee80 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-siz

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# You can calculate the distance between two points on the map based on their `Lat` and `Long` values using the following method:

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

distance_coastline = calculate_distance(28.563197, -80.576820, 28.563, -80.56792)
print(distance_coastline)
# Out:
# 0.8697364063937639

# %% [markdown]
# *TODO:* After obtained its coordinate, create a `folium.Marker` to show the distance

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
# distance_marker = folium.Marker(
#    coordinate,
#    icon=DivIcon(
#        icon_size=(20,20),
#        icon_anchor=(0,0),
#        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
#        )
#    )
coordinate = [28.563, -80.56792]
distance_marker = folium.Marker(
    coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
        )
    )

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# lines=folium.PolyLine(locations=coordinates, weight=1)
coast_coordinate = (28.563, -80.56792)
site_coordinate = (28.563197, -80.576820)
lines=folium.PolyLine([coast_coordinate,site_coordinate], weight=1)
site_map.add_child(lines)
site_map.add_child(distance_marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7433eda5e30fa239bf21ccac5c93b8d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7433eda5e30fa239bf21ccac5c93b8d1 = L.map(
#                 &quot;map_7433eda5e30fa239bf21ccac5c93b8d1&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bc08ae4d61e4a0f30a6a3d90dc099cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var circle_6836870cc95664cdedb8ff27e7b36775 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_5fd0032ab407beec48f6bbc058c696bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_765b0e0ebb2743773a4ed2e51f6bf3b4 = $(`&lt;div id=&quot;html_765b0e0ebb2743773a4ed2e51f6bf3b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#             popup_5fd0032ab407beec48f6bbc058c696bd.setContent(html_765b0e0ebb2743773a4ed2e51f6bf3b4);
#
#
#         circle_6836870cc95664cdedb8ff27e7b36775.bindPopup(popup_5fd0032ab407beec48f6bbc058c696bd)
#         ;
#
#
#
#
#             var marker_2cf6c28528b6b0a339b7b8ac4b3c8d98 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_0349f1d1c9dca8f28e5d4d1baae9939d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_2cf6c28528b6b0a339b7b8ac4b3c8d98.setIcon(div_icon_0349f1d1c9dca8f28e5d4d1baae9939d);
#
#
#             var circle_d7af11820a10e23a8be13867d9ee051f = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#         var popup_a6764e96a121706a5150cc80d2178cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3b4ea0e9d4bc9be6138e4295d666678 = $(`&lt;div id=&quot;html_f3b4ea0e9d4bc9be6138e4295d666678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#             popup_a6764e96a121706a5150cc80d2178cab.setContent(html_f3b4ea0e9d4bc9be6138e4295d666678);
#
#
#         circle_d7af11820a10e23a8be13867d9ee051f.bindPopup(popup_a6764e96a121706a5150cc80d2178cab)
#         ;
#
#
#
#
#             var marker_6e4c61a95c0f589a254b6175d708c8c3 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_7433eda5e30fa239bf21ccac5c93b8d1);
#
#
#             var div_icon_75437d8d08efc7da8af66ce66cb3ee80 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-siz

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png" />
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png" />
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png" />
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png" />
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

## manually collected coordinates for closest city, railway and highway
proximities_raw = [
    {
        "Launch_Site":"CCAFS LC-40",
        "Lat":28.562301968,
        "Long":-80.577356475,
        "closest_city_Lat": 28.40106,
        "closest_city_Long": -80.60463,
        "closest_railway_Lat": 28.5722,
        "closest_railway_Long": -80.58523,
        "closest_highway_Lat": 28.5627,
        "closest_highway_Long": -80.57073,
        "closest_coast_Lat": 28.563,
        "closest_coast_Long": -80.56792
    },
    {
        "Launch_Site":"CCAFS SLC-40",
        "Lat":28.5631971774,
        "Long":-80.5768200312,
        "closest_city_Lat": 28.40106,
        "closest_city_Long": -80.60463,
        "closest_railway_Lat": 28.5722,
        "closest_railway_Long": -80.58523,
        "closest_highway_Lat": 28.5627,
        "closest_highway_Long": -80.57073,
        "closest_coast_Lat": 28.563,
        "closest_coast_Long": -80.56792
    },
    {
        "Launch_Site":"KSC LC-39A",
        "Lat":28.5732545704,
        "Long":-80.6468952896,
        "closest_city_Lat":28.61195,
        "closest_city_Long":-80.81268,
        "closest_railway_Lat":28.5741,
        "closest_railway_Long":-80.6543,
        "closest_highway_Lat":28.5734,
        "closest_highway_Long":-80.6557,
        "closest_coast_Lat": 28.563,
        "closest_coast_Long": -80.56792
    },
    {
        "Launch_Site":"VAFB SLC-4E",
        "Lat":34.6328341618,
        "Long":-120.6107455307,
        "closest_city_Lat":34.63858, 
        "closest_city_Long": -120.45959,
        "closest_railway_Lat":34.6352, 
        "closest_railway_Long": -120.62418,
        "closest_highway_Lat":34.67458, 
        "closest_highway_Long": -120.56954,
        "closest_coast_Lat": 34.63373,
        "closest_coast_Long": -120.62601
    }
]
# build data frame
proximities_df = pd.DataFrame(proximities_raw)

proximities_df['city_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_city_Lat'], x['closest_city_Long']), axis=1)
proximities_df['railway_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_railway_Lat'], x['closest_railway_Long']), axis=1)
proximities_df['highway_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_highway_Lat'], x['closest_highway_Long']), axis=1)
proximities_df['coast_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_coast_Lat'], x['closest_coast_Long']), axis=1)

proximities_df.head()
# Out:
#     Launch_Site        Lat        Long  closest_city_Lat  closest_city_Long  \
# 0   CCAFS LC-40  28.562302  -80.577356          28.40106          -80.60463
# 1  CCAFS SLC-40  28.563197  -80.576820          28.40106          -80.60463
# 2    KSC LC-39A  28.573255  -80.646895          28.61195          -80.81268
# 3   VAFB SLC-4E  34.632834 -120.610746          34.63858         -120.45959
#
#    closest_railway_Lat  closest_railway_Long  closest_highway_Lat  \
# 0              28.5722             -80.58523             28.56270
# 1              28.5722             -80.58523             28.56270
# 2              28.5741             -80.65430             28.57340
# 3              34.6352            -120.62418             34.67458
#
#    closest_highway_Long  closest_coast_Lat  closest_coast_Long  city_distance  \
# 0             -80.57073           28.56300           -80.56792      18.132052
# 1             -80.57073           28.56300           -80.56792      18.238292
# 2             -80.65570           28.56300           -80.56792      16.753631
# 3            -120.56954           34.63373          -120.62601      13.848197
#
#    railway_distance  highway_distance  coast_distance
# 0          1.343019          0.648871        0.925137
# 1          1.295266          0.597514        0.869740
# 2          0.729397          0.860220        7.798760
# 3          1.257366          5.981272        1.400563

# %%
# plot all proximities 
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
for i,r in proximities_df.iterrows():
    site_coordinate = (r.Lat, r.Long)
    
    city_coordinate = (r.closest_city_Lat, r.closest_city_Long)
    railway_coordinate = (r.closest_railway_Lat, r.closest_railway_Long)
    highway_coordinate = (r.closest_highway_Lat, r.closest_railway_Long)
    coast_coordinate = (r.closest_coast_Lat, r.closest_coast_Long)

    # city
    distance_city = r.city_distance
    #city_coordinate = [r.closest_city_Lat,r.closest_city_Long]
    city_marker = folium.Marker( [r.closest_city_Lat, r.closest_city_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city),))
    city_line=folium.PolyLine([site_coordinate,city_coordinate], weight=1)
    site_map.add_child(city_marker)
    site_map.add_child(city_line)
    
    # railway
    distance_railway = r.railway_distance
    railway_marker = folium.Marker( [r.closest_railway_Lat, r.closest_railway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway),))
    railway_line=folium.PolyLine([site_coordinate,railway_coordinate], weight=1)
    site_map.add_child(railway_marker)
    site_map.add_child(railway_line)
    
    # highway
    distance_highway = r.highway_distance
    highway_marker = folium.Marker( [r.closest_highway_Lat, r.closest_highway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway),))
    highway_line=folium.PolyLine([site_coordinate,highway_coordinate], weight=1)
    site_map.add_child(highway_marker)
    site_map.add_child(highway_line)
    
    # coast
    distance_coast = r.coast_distance
    coast_marker = folium.Marker( [r.closest_coast_Lat, r.closest_coast_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coast),))
    coast_line=folium.PolyLine([site_coordinate,coast_coordinate], weight=1)
    site_map.add_child(coast_marker)
    site_map.add_child(coast_line)
#
#check new data frame 
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c679dfc2ace2d8020340d93fcc091816 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c679dfc2ace2d8020340d93fcc091816&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c679dfc2ace2d8020340d93fcc091816 = L.map(
#                 &quot;map_c679dfc2ace2d8020340d93fcc091816&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93209d0952a37c630db7af6bbe3d9e9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var marker_c83892aa58a262042edbedaf4c172e51 = L.marker(
#                 [28.40106, -80.60463],
#                 {}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var div_icon_86bd482fc999ff38311ffcb5ae37720a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e     18.13 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_c83892aa58a262042edbedaf4c172e51.setIcon(div_icon_86bd482fc999ff38311ffcb5ae37720a);
#
#
#             var poly_line_bb5204c73922780ce6fdba317f014481 = L.polyline(
#                 [[28.562301968, -80.577356475], [28.40106, -80.60463]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var marker_a42d1b15047f24108ec3bf2001061947 = L.marker(
#                 [28.5722, -80.58523],
#                 {}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var div_icon_5212a690c2c15c8dedf2328dd2f2baa2 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      1.34 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_a42d1b15047f24108ec3bf2001061947.setIcon(div_icon_5212a690c2c15c8dedf2328dd2f2baa2);
#
#
#             var poly_line_b54d22f37a10f2b167485cfb3454ecf6 = L.polyline(
#                 [[28.562301968, -80.577356475], [28.5722, -80.58523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var marker_16776fcc5c7f8abb3dc81b2ec6c91f06 = L.marker(
#                 [28.5627, -80.57073],
#                 {}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var div_icon_3a2a83f8cabe40b89fe9564be1bc7d42 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      0.65 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_16776fcc5c7f8abb3dc81b2ec6c91f06.setIcon(div_icon_3a2a83f8cabe40b89fe9564be1bc7d42);
#
#
#             var poly_line_28a54bdb076f5c61a9000906054f39c4 = L.polyline(
#                 [[28.562301968, -80.577356475], [28.5627, -80.58523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c679dfc2ace2d8020340d93fcc091816);
#
#
#             var marker_2a372ccac8958deabce008b533cf3e4f = L.marker(

# %%
proximities_df.head()
# Out:
#     Launch_Site        Lat        Long  closest_city_Lat  closest_city_Long  \
# 0   CCAFS LC-40  28.562302  -80.577356          28.40106          -80.60463
# 1  CCAFS SLC-40  28.563197  -80.576820          28.40106          -80.60463
# 2    KSC LC-39A  28.573255  -80.646895          28.61195          -80.81268
# 3   VAFB SLC-4E  34.632834 -120.610746          34.63858         -120.45959
#
#    closest_railway_Lat  closest_railway_Long  closest_highway_Lat  \
# 0              28.5722             -80.58523             28.56270
# 1              28.5722             -80.58523             28.56270
# 2              28.5741             -80.65430             28.57340
# 3              34.6352            -120.62418             34.67458
#
#    closest_highway_Long  closest_coast_Lat  closest_coast_Long  distance_city  \
# 0             -80.57073           28.56300           -80.56792      18.132052
# 1             -80.57073           28.56300           -80.56792      18.238292
# 2             -80.65570           28.56300           -80.56792      16.753631
# 3            -120.56954           34.63373          -120.62601      13.848197
#
#    distance_railway  distance_highway  distance_coast
# 0          1.343019          0.648871        0.925137
# 1          1.295266          0.597514        0.869740
# 2          0.729397          0.860220        7.798760
# 3          1.257366          5.981272        1.400563

# %%
proximities_df['city_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_city_Lat'], x['closest_city_Long']), axis=1)
proximities_df['railway_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_railway_Lat'], x['closest_railway_Long']), axis=1)
proximities_df['highway_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_highway_Lat'], x['closest_highway_Long']), axis=1)
proximities_df['coast_distance'] = proximities_df.apply(lambda x: calculate_distance(x['Lat'], x['Long'], x['closest_coast_Lat'], x['closest_coast_Long']), axis=1)
proximities_df
# Out:
#     Launch_Site        Lat        Long  closest_city_Lat  closest_city_Long  \
# 0   CCAFS LC-40  28.562302  -80.577356          28.40106          -80.60463
# 1  CCAFS SLC-40  28.563197  -80.576820          28.40106          -80.60463
# 2    KSC LC-39A  28.573255  -80.646895          28.61195          -80.81268
# 3   VAFB SLC-4E  34.632834 -120.610746          34.63858         -120.45959
#
#    closest_railway_Lat  closest_railway_Long  closest_highway_Lat  \
# 0              28.5722             -80.58523             28.56270
# 1              28.5722             -80.58523             28.56270
# 2              28.5741             -80.65430             28.57340
# 3              34.6352            -120.62418             34.67458
#
#    closest_highway_Long  closest_coast_Lat  closest_coast_Long  distance_city  \
# 0             -80.57073           28.56300           -80.56792      18.132052
# 1             -80.57073           28.56300           -80.56792      18.238292
# 2             -80.65570           28.56300           -80.56792      16.753631
# 3            -120.56954           34.63373          -120.62601      13.848197
#
#    distance_railway  distance_highway  distance_coast  city_distance
# 0          1.343019          0.648871        0.925137      18.132052
# 1          1.295266          0.597514        0.869740      18.238292
# 2          0.729397          0.860220        7.798760      16.753631
# 3          1.257366          5.981272        1.400563      13.848197

# %%
# filter for site: CCAFS SLC-40
proximities_df_CCAFS_SLC_40 = proximities_df[proximities_df['Launch_Site']=='CCAFS SLC-40']

site_coordinate = (proximities_df_CCAFS_SLC_40['Lat'], proximities_df_CCAFS_SLC_40['Long'])
site_map = folium.Map(location=site_coordinate, zoom_start=12)



for i,r in proximities_df_CCAFS_SLC_40.iterrows():
    site_coordinate = (r.Lat, r.Long)
    
    city_coordinate = (r.closest_city_Lat, r.closest_city_Long)
    railway_coordinate = (r.closest_railway_Lat, r.closest_railway_Long)
    highway_coordinate = (r.closest_highway_Lat, r.closest_railway_Long)
    coast_coordinate = (r.closest_coast_Lat, r.closest_coast_Long)

    # city
    distance_city = r.city_distance
    #city_coordinate = [r.closest_city_Lat,r.closest_city_Long]
    city_marker = folium.Marker( [r.closest_city_Lat, r.closest_city_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city),))
    city_line=folium.PolyLine([site_coordinate,city_coordinate], weight=1)
    site_map.add_child(city_marker)
    site_map.add_child(city_line)
    
    # railway
    distance_railway = r.railway_distance
    railway_marker = folium.Marker( [r.closest_railway_Lat, r.closest_railway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway),))
    railway_line=folium.PolyLine([site_coordinate,railway_coordinate], weight=1)
    site_map.add_child(railway_marker)
    site_map.add_child(railway_line)
    
    # highway
    distance_highway = r.highway_distance
    highway_marker = folium.Marker( [r.closest_highway_Lat, r.closest_highway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway),))
    highway_line=folium.PolyLine([site_coordinate,highway_coordinate], weight=1)
    site_map.add_child(highway_marker)
    site_map.add_child(highway_line)
    
    # coast
    distance_coast = r.coast_distance
    coast_marker = folium.Marker( [r.closest_coast_Lat, r.closest_coast_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coast),))
    coast_line=folium.PolyLine([site_coordinate,coast_coordinate], weight=1)
    site_map.add_child(coast_marker)
    site_map.add_child(coast_line)
#
#check new data frame 
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0527f686698b9b83ef1697dbe9677a4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0527f686698b9b83ef1697dbe9677a4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0527f686698b9b83ef1697dbe9677a4e = L.map(
#                 &quot;map_0527f686698b9b83ef1697dbe9677a4e&quot;,
#                 {
#                     center: [28.5631971774, -80.5768200312],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2fcdaba892330e448bd1ff0f86d29b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var marker_ecfd60c6ae20b51f907e28b708c9a1fa = L.marker(
#                 [28.40106, -80.60463],
#                 {}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var div_icon_27c71fcee94dd266dc07a73cc5b93b59 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e     18.24 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_ecfd60c6ae20b51f907e28b708c9a1fa.setIcon(div_icon_27c71fcee94dd266dc07a73cc5b93b59);
#
#
#             var poly_line_e2c256eb5a624e9b421ca8fec03494a2 = L.polyline(
#                 [[28.5631971774, -80.5768200312], [28.40106, -80.60463]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var marker_463b8bca02f507d9cb9cc3fdeae5992d = L.marker(
#                 [28.5722, -80.58523],
#                 {}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var div_icon_c46d5142e53c258fab906166cf9bafa1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      1.30 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_463b8bca02f507d9cb9cc3fdeae5992d.setIcon(div_icon_c46d5142e53c258fab906166cf9bafa1);
#
#
#             var poly_line_78eabcc6dea427efc499021c6c4da298 = L.polyline(
#                 [[28.5631971774, -80.5768200312], [28.5722, -80.58523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var marker_4d57509c479494b40d50e907295b01bd = L.marker(
#                 [28.5627, -80.57073],
#                 {}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var div_icon_96909f837eff595b47e7baec8eee1ffc = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      0.60 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_4d57509c479494b40d50e907295b01bd.setIcon(div_icon_96909f837eff595b47e7baec8eee1ffc);
#
#
#             var poly_line_b29cf265e0b8919918099ee900d29847 = L.polyline(
#                 [[28.5631971774, -80.5768200312], [28.5627, -80.58523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0527f686698b9b83ef1697dbe9677a4e);
#
#
#             var marker_a9147abe5e33818c927ef9320380a26f = L.marker(

# %%
# filter for site: KSC LC-39A
proximities_df_KSC_LC_39A = proximities_df[proximities_df['Launch_Site']=='KSC LC-39A']
site_coordinate = (proximities_df_KSC_LC_39A['Lat'], proximities_df_KSC_LC_39A['Long'])
site_map = folium.Map(location=site_coordinate, zoom_start=12)

for i,r in proximities_df_KSC_LC_39A.iterrows():
    site_coordinate = (r.Lat, r.Long)
    
    city_coordinate = (r.closest_city_Lat, r.closest_city_Long)
    railway_coordinate = (r.closest_railway_Lat, r.closest_railway_Long)
    highway_coordinate = (r.closest_highway_Lat, r.closest_railway_Long)
    coast_coordinate = (r.closest_coast_Lat, r.closest_coast_Long)

    # city
    distance_city = r.city_distance
    #city_coordinate = [r.closest_city_Lat,r.closest_city_Long]
    city_marker = folium.Marker( [r.closest_city_Lat, r.closest_city_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city),))
    city_line=folium.PolyLine([site_coordinate,city_coordinate], weight=1)
    site_map.add_child(city_marker)
    site_map.add_child(city_line)
    
    # railway
    distance_railway = r.railway_distance
    railway_marker = folium.Marker( [r.closest_railway_Lat, r.closest_railway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway),))
    railway_line=folium.PolyLine([site_coordinate,railway_coordinate], weight=1)
    site_map.add_child(railway_marker)
    site_map.add_child(railway_line)
    
    # highway
    distance_highway = r.highway_distance
    highway_marker = folium.Marker( [r.closest_highway_Lat, r.closest_highway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway),))
    highway_line=folium.PolyLine([site_coordinate,highway_coordinate], weight=1)
    site_map.add_child(highway_marker)
    site_map.add_child(highway_line)
    
    # coast
    distance_coast = r.coast_distance
    coast_marker = folium.Marker( [r.closest_coast_Lat, r.closest_coast_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coast),))
    coast_line=folium.PolyLine([site_coordinate,coast_coordinate], weight=1)
    site_map.add_child(coast_marker)
    site_map.add_child(coast_line)
#
#check new data frame 
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c56de6126e5a2ef9d53ee55a52bf470b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c56de6126e5a2ef9d53ee55a52bf470b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c56de6126e5a2ef9d53ee55a52bf470b = L.map(
#                 &quot;map_c56de6126e5a2ef9d53ee55a52bf470b&quot;,
#                 {
#                     center: [28.5732545704, -80.6468952896],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cadfac8e50a47a6fc9cdbeb19d1408b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var marker_ed6dd69f64d3be63ebf475b4c06ac6a4 = L.marker(
#                 [28.61195, -80.81268],
#                 {}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var div_icon_7db5b4e030d33d96b2c971b16c869ea3 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e     16.75 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_ed6dd69f64d3be63ebf475b4c06ac6a4.setIcon(div_icon_7db5b4e030d33d96b2c971b16c869ea3);
#
#
#             var poly_line_b23dd4495215ca1cea0815d6891490ea = L.polyline(
#                 [[28.5732545704, -80.6468952896], [28.61195, -80.81268]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var marker_09b5ac52eae3433c6c3b0de0abc26a84 = L.marker(
#                 [28.5741, -80.6543],
#                 {}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var div_icon_a4a5b7646c0ad224e321f2b71454b142 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      0.73 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_09b5ac52eae3433c6c3b0de0abc26a84.setIcon(div_icon_a4a5b7646c0ad224e321f2b71454b142);
#
#
#             var poly_line_3316d7657153af86225b198329c525cb = L.polyline(
#                 [[28.5732545704, -80.6468952896], [28.5741, -80.6543]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var marker_83448a94746110fcbdbac53401c9f6b6 = L.marker(
#                 [28.5734, -80.6557],
#                 {}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var div_icon_02d9e8ae99d87ef966b52f261649481e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      0.86 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_83448a94746110fcbdbac53401c9f6b6.setIcon(div_icon_02d9e8ae99d87ef966b52f261649481e);
#
#
#             var poly_line_0897dfc899ea875103058f6d755a91a5 = L.polyline(
#                 [[28.5732545704, -80.6468952896], [28.5734, -80.6543]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c56de6126e5a2ef9d53ee55a52bf470b);
#
#
#             var marker_fcf07dbedc652d94bb7ea149452140f6 = L.marker(

# %%
# filter for site: VAFB SLC-4E
proximities_df_VAFB_SLC_4E = proximities_df[proximities_df['Launch_Site']=='VAFB SLC-4E']
site_coordinate = (proximities_df_VAFB_SLC_4E['Lat'], proximities_df_VAFB_SLC_4E['Long'])
site_map = folium.Map(location=site_coordinate, zoom_start=12)

proximities_df_KSC_LC_39A = proximities_df[proximities_df['Launch_Site']=='KSC LC-39A']

for i,r in proximities_df_VAFB_SLC_4E.iterrows():
    site_coordinate = (r.Lat, r.Long)
    
    city_coordinate = (r.closest_city_Lat, r.closest_city_Long)
    railway_coordinate = (r.closest_railway_Lat, r.closest_railway_Long)
    highway_coordinate = (r.closest_highway_Lat, r.closest_railway_Long)
    coast_coordinate = (r.closest_coast_Lat, r.closest_coast_Long)

    # city
    distance_city = r.city_distance
    #city_coordinate = [r.closest_city_Lat,r.closest_city_Long]
    city_marker = folium.Marker( [r.closest_city_Lat, r.closest_city_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city),))
    city_line=folium.PolyLine([site_coordinate,city_coordinate], weight=1)
    site_map.add_child(city_marker)
    site_map.add_child(city_line)
    
    # railway
    distance_railway = r.railway_distance
    railway_marker = folium.Marker( [r.closest_railway_Lat, r.closest_railway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway),))
    railway_line=folium.PolyLine([site_coordinate,railway_coordinate], weight=1)
    site_map.add_child(railway_marker)
    site_map.add_child(railway_line)
    
    # highway
    distance_highway = r.highway_distance
    highway_marker = folium.Marker( [r.closest_highway_Lat, r.closest_highway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway),))
    highway_line=folium.PolyLine([site_coordinate,highway_coordinate], weight=1)
    site_map.add_child(highway_marker)
    site_map.add_child(highway_line)
    
    # coast
    distance_coast = r.coast_distance
    coast_marker = folium.Marker( [r.closest_coast_Lat, r.closest_coast_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coast),))
    coast_line=folium.PolyLine([site_coordinate,coast_coordinate], weight=1)
    site_map.add_child(coast_marker)
    site_map.add_child(coast_line)
#
#check new data frame 
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7014a40ca83864a152feb17d12a90327 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7014a40ca83864a152feb17d12a90327&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7014a40ca83864a152feb17d12a90327 = L.map(
#                 &quot;map_7014a40ca83864a152feb17d12a90327&quot;,
#                 {
#                     center: [34.6328341618, -120.6107455307],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dca5c7e28c493408bfd4e4ef4ece4089 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var marker_4616b6e1dcbc96a4d67a4be2f38d60bb = L.marker(
#                 [34.63858, -120.45959],
#                 {}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var div_icon_279a06f2814a6d8c7f6b1ef0c1726a40 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e     13.85 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_4616b6e1dcbc96a4d67a4be2f38d60bb.setIcon(div_icon_279a06f2814a6d8c7f6b1ef0c1726a40);
#
#
#             var poly_line_df16704ce3872003756d41a997f178bd = L.polyline(
#                 [[34.6328341618, -120.6107455307], [34.63858, -120.45959]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var marker_9c69901a6e7fb32e5329761bb3f54bee = L.marker(
#                 [34.6352, -120.62418],
#                 {}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var div_icon_406535230dad94a731d2c7f254d1084a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      1.26 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_9c69901a6e7fb32e5329761bb3f54bee.setIcon(div_icon_406535230dad94a731d2c7f254d1084a);
#
#
#             var poly_line_47c7ceaf2f645e13ed3557eea08c7e1e = L.polyline(
#                 [[34.6328341618, -120.6107455307], [34.6352, -120.62418]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var marker_36e34ef2be2ebb7d49b7b53d69527226 = L.marker(
#                 [34.67458, -120.56954],
#                 {}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var div_icon_8763563686c5ecf185332cba4373c933 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      5.98 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_36e34ef2be2ebb7d49b7b53d69527226.setIcon(div_icon_8763563686c5ecf185332cba4373c933);
#
#
#             var poly_line_5b81b0e6d94b64d22d881d69f37482a3 = L.polyline(
#                 [[34.6328341618, -120.6107455307], [34.67458, -120.62418]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7014a40ca83864a152feb17d12a90327);
#
#
#             var marker_cb70bc6b77b6863d0a7efae7e5651a9e = L.marke

# %%
# filter for site: CCAFS LC-40
proximities_df_CCAFS_LC_40 = proximities_df[proximities_df['Launch_Site']=='CCAFS LC-40']
site_coordinate = (proximities_df_CCAFS_LC_40['Lat'], proximities_df_CCAFS_LC_40['Long'])
site_map = folium.Map(location=site_coordinate, zoom_start=12)


for i,r in proximities_df_CCAFS_LC_40.iterrows():
    site_coordinate = (r.Lat, r.Long)
    
    city_coordinate = (r.closest_city_Lat, r.closest_city_Long)
    railway_coordinate = (r.closest_railway_Lat, r.closest_railway_Long)
    highway_coordinate = (r.closest_highway_Lat, r.closest_railway_Long)
    coast_coordinate = (r.closest_coast_Lat, r.closest_coast_Long)

    # city
    distance_city = r.city_distance
    #city_coordinate = [r.closest_city_Lat,r.closest_city_Long]
    city_marker = folium.Marker( [r.closest_city_Lat, r.closest_city_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city),))
    city_line=folium.PolyLine([site_coordinate,city_coordinate], weight=1)
    site_map.add_child(city_marker)
    site_map.add_child(city_line)
    
    # railway
    distance_railway = r.railway_distance
    railway_marker = folium.Marker( [r.closest_railway_Lat, r.closest_railway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway),))
    railway_line=folium.PolyLine([site_coordinate,railway_coordinate], weight=1)
    site_map.add_child(railway_marker)
    site_map.add_child(railway_line)
    
    # highway
    distance_highway = r.highway_distance
    highway_marker = folium.Marker( [r.closest_highway_Lat, r.closest_highway_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway),))
    highway_line=folium.PolyLine([site_coordinate,highway_coordinate], weight=1)
    site_map.add_child(highway_marker)
    site_map.add_child(highway_line)
    
    # coast
    distance_coast = r.coast_distance
    coast_marker = folium.Marker( [r.closest_coast_Lat, r.closest_coast_Long],
                                icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0),
                                html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coast),))
    coast_line=folium.PolyLine([site_coordinate,coast_coordinate], weight=1)
    site_map.add_child(coast_marker)
    site_map.add_child(coast_line)
#
#check new data frame 
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c53e1fbda7330f0b3463d2e03584701a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c53e1fbda7330f0b3463d2e03584701a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c53e1fbda7330f0b3463d2e03584701a = L.map(
#                 &quot;map_c53e1fbda7330f0b3463d2e03584701a&quot;,
#                 {
#                     center: [28.562301968, -80.577356475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad48770d327d9ea96c82d6b642bfa1c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var marker_17a36f844e91902b5deee0ba4b2cddb7 = L.marker(
#                 [28.40106, -80.60463],
#                 {}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var div_icon_d30862bdd7002b0dae0327ba82a7a401 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e     18.13 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_17a36f844e91902b5deee0ba4b2cddb7.setIcon(div_icon_d30862bdd7002b0dae0327ba82a7a401);
#
#
#             var poly_line_8ea1a5c3efe9afba6706759d041195d0 = L.polyline(
#                 [[28.562301968, -80.577356475], [28.40106, -80.60463]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var marker_1df94553f74c9a15770d2acbb3c1232b = L.marker(
#                 [28.5722, -80.58523],
#                 {}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var div_icon_496c6ec7924bc1adf98f6abab27002c5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      1.34 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_1df94553f74c9a15770d2acbb3c1232b.setIcon(div_icon_496c6ec7924bc1adf98f6abab27002c5);
#
#
#             var poly_line_889685c3808279622da05b2c8505c101 = L.polyline(
#                 [[28.562301968, -80.577356475], [28.5722, -80.58523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var marker_ffaa630a358d46c21445c39018f1b1a2 = L.marker(
#                 [28.5627, -80.57073],
#                 {}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var div_icon_0f81a716b64d92c9471e0ab16cd4a621 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      0.65 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_ffaa630a358d46c21445c39018f1b1a2.setIcon(div_icon_0f81a716b64d92c9471e0ab16cd4a621);
#
#
#             var poly_line_ab9c553fc814f002550bf7d6be65ef90 = L.polyline(
#                 [[28.562301968, -80.577356475], [28.5627, -80.58523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c53e1fbda7330f0b3463d2e03584701a);
#
#
#             var marker_b4bbb52b9d0e80a9ed282f62e4af4dba = L.marker(
#                 [

# %%
proximities_df[['Launch_Site','city_distance','railway_distance','highway_distance','coast_distance']]
# Out:
#     Launch_Site  city_distance  railway_distance  highway_distance  \
# 0   CCAFS LC-40      18.132052          1.343019          0.648871
# 1  CCAFS SLC-40      18.238292          1.295266          0.597514
# 2    KSC LC-39A      16.753631          0.729397          0.860220
# 3   VAFB SLC-4E      13.848197          1.257366          5.981272
#
#    coast_distance
# 0        0.925137
# 1        0.869740
# 2        7.798760
# 3        1.400563

# %% [markdown]
# ## After you plot distance lines to the proximities, you can answer the following questions easily:
#
# ### Are launch sites in close proximity to railways?
#  - Yes, sites are close to railways
# ### Are launch sites in close proximity to highways?
#  - Yes, sites are close to highways
# ### Are launch sites in close proximity to coastline?
#  - Yes, sites are relatively close to coastlines
# ### Do launch sites keep certain distance away from cities?
#  - Sites are a minimum of 13 KM away from cities, likely to minimize the impact of possible launch or landing failures.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Joseph Santarcangelo

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-05-26        | 1.0     | Yan        | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
